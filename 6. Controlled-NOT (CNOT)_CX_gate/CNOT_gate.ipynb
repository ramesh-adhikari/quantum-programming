# %%
# Rule:

# If the control qubit is |0⟩, do nothing to the target.

# If the control qubit is |1⟩, flip the target qubit (apply an X gate).

# %%
from qiskit import *
from qiskit.visualization import plot_bloch_multivector, plot_histogram, array_to_latex ,plot_state_qsphere

# %%
circuit = QuantumCircuit(2) # initialize circuit with 3 qubits
circuit.draw()
# Out:
#
# q_0:
#
# q_1:

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
circuit.remove_final_measurements()  # no measurements allowed
statevector = Statevector(circuit) # Create a Statevector object representing the quantum state of the circuit
print(statevector.data)
plot_bloch_multivector(statevector) # Visualize the quantum state on the Bloch sphere for each qubit
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
circuit = QuantumCircuit(2) # initialize circuit with 2 qubits
# TO apply CNOT Gate
circuit.cx(0,1) # first parameter is control qubit index by 0 and second parameter is targit qubit index by 1
circuit.draw()
# Out:
#
# q_0: ──■──
#      ┌─┴─┐
# q_1: ┤ X ├
#      └───┘

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
circuit.remove_final_measurements()  # no measurements allowed
statevector = Statevector(circuit) # Create a Statevector object representing the quantum state of the circuit
print(statevector.data)
plot_bloch_multivector(statevector) # Visualize the quantum state on the Bloch sphere for each qubit
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
# Both qubits are in zero state, since the control qubit was zero, nothing happend
#Now lets insert X gate to flip that control to one just before cnot

# %%
circuit = QuantumCircuit(2) # initialize circuit with 2 qubits
circuit.x(0) # flip the first qubit from 0 to 1
# TO apply CNOT Gate
circuit.cx(0,1) # first parameter is control qubit index by 0 and second parameter is targit qubit index by 1
circuit.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
circuit.remove_final_measurements()  # no measurements allowed
statevector = Statevector(circuit) # Create a Statevector object representing the quantum state of the circuit
print(statevector.data)
plot_bloch_multivector(statevector) # Visualize the quantum state on the Bloch sphere for each qubit
# Out:
# [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
